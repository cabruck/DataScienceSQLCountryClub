# %% [markdown]
# ## 8.3 Country Club case study

# %% [markdown]
# Queries a local SQLite db file, first using assignment's provided query method, and later switching to pandas read_sql_query for better output display.

# %%
import sqlite3
from sqlite3 import Error
import pandas as pd
import os

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        # print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

# %%
def do_query(db_file,query):
    """
    Query all rows in the tasks table
    :param db_file: database file
    :param query: the query
    :return:
    """
    conn = create_connection(db_file)
    with conn: 
        cur = conn.cursor()
        cur.execute(query) 
        rows = cur.fetchall()
        for row in rows:
            print(row)

# %%
# "sqlite_db_pythonsqlite.db" needs to be in working directory
os.getcwd()
# Out:
# '/Users/Carsten/OneDrive/Documents/Springboard/git_repositories/DataScienceSQLCountryClub'

# %%
db_file = "sqlite_db_pythonsqlite.db"

# %%
query = """
/* Q1: Some of the facilities charge a fee to members, but some do not.
Write a SQL query to produce a list of the names of the facilities that do. */
SELECT name, membercost
FROM Facilities
WHERE membercost > 0;
"""

# %%
do_query(db_file,query)
# Out:
# ('Tennis Court 1', 5)
# ('Tennis Court 2', 5)
# ('Massage Room 1', 9.9)
# ('Massage Room 2', 9.9)
# ('Squash Court', 3.5)

# %% [markdown]
# I don't like format of db_query output.  Switch to using pandas for query and formatting into dataframe for subsequent queries

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#              name  membercost
# 0  Tennis Court 1         5.0
# 1  Tennis Court 2         5.0
# 2  Massage Room 1         9.9
# 3  Massage Room 2         9.9
# 4    Squash Court         3.5

# %%
query = """
/* Q2: How many facilities do not charge a fee to members? */
SELECT COUNT(*) AS 'Count_of_nocharge_facilities'
FROM Facilities
WHERE membercost = 0;
"""

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#    Count_of_nocharge_facilities
# 0                             4

# %%
query = """
/* Q3: Write an SQL query to show a list of facilities that charge a fee to members,
where the fee is less than 20% of the facility's monthly maintenance cost.
Return the facid, facility name, member cost, and monthly maintenance of the
facilities in question. */

SELECT facid,
	   name AS 'facility name',
	   membercost AS 'member cost',
	   monthlymaintenance AS 'monthly maintenance cost'
FROM Facilities
WHERE membercost > 0 AND
      (membercost < 0.20 *
			(SELECT AVG(monthlymaintenance)
	 		 FROM Facilities)
	  );
"""

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#    facid   facility name  member cost  monthly maintenance cost
# 0      0  Tennis Court 1          5.0                       200
# 1      1  Tennis Court 2          5.0                       200
# 2      4  Massage Room 1          9.9                      3000
# 3      5  Massage Room 2          9.9                      3000
# 4      6    Squash Court          3.5                        80

# %%
query = """
/* Q4: Write an SQL query to retrieve the details of facilities with ID 1 and 5.
Try writing the query without using the OR operator. */

SELECT *
FROM Facilities
WHERE facid IN (1,5);
"""

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#    facid            name  membercost  guestcost  initialoutlay  \
# 0      1  Tennis Court 2         5.0         25           8000
# 1      5  Massage Room 2         9.9         80           4000
#
#    monthlymaintenance
# 0                 200
# 1                3000

# %%
query = """
/* Q5: Produce a list of facilities, with each labelled as
'cheap' or 'expensive', depending on if their monthly maintenance cost is
more than $100. Return the name and monthly maintenance of the facilities
in question. */

SELECT name,
	   monthlymaintenance,
	   (CASE WHEN monthlymaintenance > 100 THEN 'expensive'
	   	ELSE 'cheap' END) AS price_category
FROM Facilities;
"""

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#               name  monthlymaintenance price_category
# 0   Tennis Court 1                 200      expensive
# 1   Tennis Court 2                 200      expensive
# 2  Badminton Court                  50          cheap
# 3     Table Tennis                  10          cheap
# 4   Massage Room 1                3000      expensive
# 5   Massage Room 2                3000      expensive
# 6     Squash Court                  80          cheap
# 7    Snooker Table                  15          cheap
# 8       Pool Table                  15          cheap

# %%
query = """
/* Q6: You'd like to get the first and last name of the last member(s)
who signed up. Try not to use the LIMIT clause for your solution. */

SELECT firstname, surname
FROM Members
WHERE joindate =
	  (SELECT MAX(joindate)
	   FROM Members);
"""

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#   firstname surname
# 0    Darren   Smith

# %%
query = """
/* Q7: Produce a list of all members who have used a tennis court.
Include in your output the name of the court, and the name of the member
formatted as a single column. Ensure no duplicate data, and order by
the member name. */

SELECT DISTINCT name, firstname||' '||surname AS fullname
FROM Bookings
INNER JOIN Facilities
	USING(facid)
INNER JOIN Members
	USING(memid)
WHERE name LIKE 'Tennis Court%'
ORDER BY surname, firstname, name;
"""

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#               name           fullname
# 0   Tennis Court 1     Florence Bader
# 1   Tennis Court 2     Florence Bader
# 2   Tennis Court 1         Anne Baker
# 3   Tennis Court 2         Anne Baker
# 4   Tennis Court 1      Timothy Baker
# 5   Tennis Court 2      Timothy Baker
# 6   Tennis Court 1         Tim Boothe
# 7   Tennis Court 2         Tim Boothe
# 8   Tennis Court 1     Gerald Butters
# 9   Tennis Court 2     Gerald Butters
# 10  Tennis Court 1        Joan Coplin
# 11  Tennis Court 1      Erica Crumpet
# 12  Tennis Court 1         Nancy Dare
# 13  Tennis Court 2         Nancy Dare
# 14  Tennis Court 1      David Farrell
# 15  Tennis Court 2      David Farrell
# 16  Tennis Court 1     Jemima Farrell
# 17  Tennis Court 2     Jemima Farrell
# 18  Tennis Court 1        GUEST GUEST
# 19  Tennis Court 2        GUEST GUEST
# 20  Tennis Court 1    Matthew Genting
# 21  Tennis Court 1          John Hunt
# 22  Tennis Court 2          John Hunt
# 23  Tennis Court 1        David Jones
# 24  Tennis Court 2        David Jones
# 25  Tennis Court 1      Douglas Jones
# 26  Tennis Court 1    Janice Joplette
# 27  Tennis Court 2    Janice Joplette
# 28  Tennis Court 1       Charles Owen
# 29  Tennis Court 2       Charles Owen
# 30  Tennis Court 1       David Pinker
# 31  Tennis Court 2  Millicent Purview
# 32  Tennis Court 1         Tim Rownam
# 33  Tennis Court 2         Tim Rownam
# 34  Tennis Court 2   Henrietta Rumney
# 35  Tennis Court 1   Ramnaresh Sarwin
# 36  Tennis Court 2   Ramnaresh Sarwin
# 37  Tennis Court 2       Darren Smith
# 38  Tennis Court 1         Jack Smith
# 39  Tennis Court 2         Jack Smith
# 40  Tennis Court 1        Tracy Smith
# 41  Tennis Court 2        Tracy Smith
# 42  Tennis Court 1    Ponder Stibbons
# 43  Tennis Court 2    Ponder Stibbons
# 44  Tennis Court 1       Burton Tracy
# 45  Tennis Court 2       Burton Tracy

# %%
query = """
/* Q8: Produce a list of bookings on the day of 2012-09-14 which
will cost the member (or guest) more than $30. Remember that guests have
different costs to members (the listed costs are per half-hour 'slot'), and
the guest user's ID is always 0. Include in your output the name of the
facility, the name of the member formatted as a single column, and the cost.
Order by descending cost, and do not use any subqueries. */

SELECT bookid,
       starttime,
       name,
       firstname || ' ' || surname as fullname,
       (CASE
        WHEN  memid=0 THEN slots*guestcost
        ELSE slots*membercost END )  AS  "total_cost"
FROM Bookings
INNER JOIN Facilities
    USING(facid)
INNER JOIN Members
    USING(memid)
WHERE starttime LIKE '2012-09-14%'
    AND total_cost >30
ORDER BY total_cost DESC;
"""

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
#     bookid            starttime            name        fullname  total_cost
# 0     2946  2012-09-14 11:00:00  Massage Room 2     GUEST GUEST       320.0
# 1     2937  2012-09-14 09:00:00  Massage Room 1     GUEST GUEST       160.0
# 2     2940  2012-09-14 13:00:00  Massage Room 1     GUEST GUEST       160.0
# 3     2942  2012-09-14 16:00:00  Massage Room 1     GUEST GUEST       160.0
# 4     2926  2012-09-14 17:00:00  Tennis Court 2     GUEST GUEST       150.0
# 5     2920  2012-09-14 16:00:00  Tennis Court 1     GUEST GUEST        75.0
# 6     2922  2012-09-14 19:00:00  Tennis Court 1     GUEST GUEST        75.0
# 7     2925  2012-09-14 14:00:00  Tennis Court 2     GUEST GUEST        75.0
# 8     2948  2012-09-14 09:30:00    Squash Court     GUEST GUEST        70.0
# 9     2941  2012-09-14 14:00:00  Massage Room 1  Jemima Farrell        39.6
# 10    2949  2012-09-14 12:30:00    Squash Court     GUEST GUEST        35.0
# 11    2951  2012-09-14 15:00:00    Squash Court     GUEST GUEST        35.0

# %%
query = """
/* Q9: This time, produce the same result as in Q8, but using a subquery. */


/* CB: I can't calculate total cost until after I join Facilities to Bookings.
The only subqueries on a pre-joined table I can think of
do row and/or column filtering, which I could do on outer query anyway.
So I can't think of a meaninful subquery in the FROM clause.
*/
"""

# %%
do_query(db_file,query)

# %%
pd.read_sql_query(query,create_connection(db_file))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-cabb5418a4d7> in <module>
# ----> 1 pd.read_sql_query(query,create_connection(db_file))
#
# ~/opt/anaconda3/envs/springboard/lib/python3.8/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     386     """
#     387     pandas_sql = pandasSQL_builder(con)
# --> 388     return pandas_sql.read_query(
#     389         sql,
#     390         index_col=index_col,
#
# ~/opt/anaconda3/envs/springboard/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1770         args = _convert_params(sql, params)
#    1771         cursor = self.execute(*args)
# -> 1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#    1774         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable
